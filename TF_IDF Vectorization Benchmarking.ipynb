# %%
import sys  
import pandas as pd
import numpy as np
sys.path.insert(0, '/Stats-Toolbox')

from statsbox import Decision_Tree
from statsbox import K_Means
from statsbox import TF_tools
df = pd.read_csv("../Amazon-data.csv")
# Out:
# /var/folders/vl/5bp0nbzd28vgxygxw50kjt4r0000gn/T/ipykernel_84709/2428769182.py:9: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Amazon-data.csv")

# %%
sentences = df['reviews.text']
x_sent = []
for s in sentences:
    x_sent.append(s)
x_sent=x_sent[500:1000]

# %%
x = x_sent[20:50]
x = (TF_tools.remove_stopwords(TF_tools.lowercase(TF_tools.remove_punctuation(x))))

# %%
x
# Out:
# [' want tablet use daily basis facebook online purchases ask better tablet',
#  ' use read books watch movies get online works great easy use',
#  ' bought replace samsung galaxy tab 3 absolutely love kindle hd 8 easy set easy find way around reason took 1 star found apps available kindle far info read online ways resolve issue',
#  ' simple kindle glass back',
#  ' throughly enjoying fire tablet play games read books pleased',
#  ' excellent screen fast response almost steal price',
#  ' much harder work android none wallpaper apps downloaded kindle store work device many apps look cheap display wise prettier responsive cheaper 49 tablet make look like android tablet google play everything harder work regular android tablet 100 exceeds expectations responsive models fire',
#  ' kindle fire dream larger screen easy read',
#  ' amazon prime 2 years new fire hd makes worth watch movies fly download battery last days use everyday',
# ...

# %%
words_set = TF_tools.get_word_set(x, 'set')
print(words_set)
# Out:
# {'set', 'loved', 'better', 'expandable', 'replacement', 'def', 'fire', 'android', 'things', '8in', 'options', 'purchases', 'download', 'best', 'steal', 'age', 'ask', 'exchanged', 'youreyes', 'tv', 'differently', 'hd8', 'personally', 'amazing', 'like', 'days', '1', 'old', 'facebook', 'waiting', 'decided', 'downloaded', 'stars', 'also', 'however', 'great', 'new', 'simple', "i'm", 'works', 'time', 'find', 'abilities', 'buy', 'loading', 'mine', 'pay', 'fork', 'around', 'font', 'dream', 'perfect', 'complaint', 'easy', 'youngest', 'improved', 'google', 'regular', 'larger', 'gift', 'overall', '2016', 'unfortunately', 'anything', 'bought', 'couple', 'available', 'magazines', 'look', 'micro', 'constant', 'alot', 'needs', 'hi', 'books', 'builtin', 'reader', '7', 'reason', 'awhile', 'storage', 'family', 'n', 'died', 'purchase', 'inch', 'stick', 'kindle', 'throughly', 'improves', 'ways', 'card', '3', 'watch', 'found', 'long', 'issue', 'work', 'even', 'movies', 'able', 'limited', 'chrome', 'prett
# ...

# %%
df_tf = TF_tools.TF_matrix(x, words_set, 'list')
df_tf_idf = TF_tools.TF_IDF(x, words_set, df_tf, 'list' )

# %%
df_tf_idf = pd.DataFrame(df_tf_idf)
df_tf_idf
# Out:
#          0         1         2         3         4         5         6    \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.028916  0.000000  0.000000  0.000000  0.000000  0.028916
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.016255  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.050223  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df_tf = TF_tools.TF_matrix(x, words_set, 'df')
df_tf_idf = TF_tools.TF_IDF(x, words_set, df_tf, 'df' )

# %%
df_tf_idf
# Out:
#           00         1        10       100         2      2016         3  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.028916  0.000000  0.000000  0.000000  0.000000  0.028916
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.016255  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.050223  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %% [markdown]
# ### Using sklearn.feature_extraction.TFidVectorizor on same data

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tr_idf_model  = TfidfVectorizer()
tf_idf_vector = tr_idf_model.fit_transform(x)
tf_idf_array = tf_idf_vector.toarray()
words_set = tr_idf_model.get_feature_names()

df_tf_idf_bench = pd.DataFrame(tf_idf_array, columns = words_set)
df_tf_idf_bench
# Out:
# /Users/abhik-mac/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#           00        10       100     2016       49        80        87  \
# 0   0.000000  0.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# 6   0.000000  0.000000  0.104380  0.00000  0.13824  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# ...

# %% [markdown]
# ### Using cosine similarity to rank the vectors

# %%
a=[]
b=[]
for i in range(5):
    a.append(TF_tools.cos_sim(df_tf_idf_bench.iloc[i],df_tf_idf_bench.iloc[i+1] ))
    b.append(TF_tools.cos_sim(df_tf_idf.iloc[i],df_tf_idf.iloc[i+1] ))

print(a)
print(b)
# Out:
# [0.1746086850696103, 0.15157476559315175, 0.06898264794862224, 0.0, 0.0]
# [0.12433555392865596, 0.11113654912372051, 0.011124874129950581, 0.0, 0.0]

# %%
query = "amazon kindle was an amazing purchase, I love my kindle"

# %%
x_set = x
x_set.append(query)

# %%
words_set = TF_tools.get_word_set(x_set, 'set')
df_tf = TF_tools.TF_matrix(x_set, words_set, 'list')
df_tf_idf = TF_tools.TF_IDF(x_set, words_set, df_tf, 'list' )

# %%
tr_idf_model  = TfidfVectorizer()
tf_idf_vector = tr_idf_model.fit_transform(x_set)
tf_idf_array = tf_idf_vector.toarray()
words_set = tr_idf_model.get_feature_names()

df_tf_idf_bench = pd.DataFrame(tf_idf_array, columns = words_set)
df_tf_idf_bench
# Out:
# /Users/abhik-mac/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#           00        10       100      2016        49        80        87  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.104582  0.000000  0.138132  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
a=[]
b=[]
for i in range(5):
    a.append(TF_tools.cos_sim(df_tf_idf_bench.iloc[i],df_tf_idf_bench.iloc[30] ))
    b.append(TF_tools.cos_sim(df_tf_idf.iloc[i],df_tf_idf.iloc[30] ))

print(np.argmax(a))
print(np.argmax(b))
# Out:
# 2
# 2

# %%
print(a)
print(b)
# Out:
# [0.0, 0.0, 0.1284770345182132, 0.12272086145859643, 0.0]
# [0.0, 0.0, 0.0342232479625587, 0.014152758248650742, 0.0]

# %%
x_set[30]
# Out:
# 'amazon kindle was an amazing purchase, I love my kindle'

# %%
x_set[2]
# Out:
# ' bought replace samsung galaxy tab 3 absolutely love kindle hd 8 easy set easy find way around reason took 1 star found apps available kindle far info read online ways resolve issue'

# %%
x_set[0]
# Out:
# ' want tablet use daily basis facebook online purchases ask better tablet'

# %%
x_set[3]
# Out:
# ' simple kindle glass back'

# %%
x_set[4]
# Out:
# ' throughly enjoying fire tablet play games read books pleased'
